# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#import dataset from data.csv file

# %%
dataset = pd.read_csv('data.csv')
dataset = dataset.fillna(0)

# %%
dataset
# Out:
#            date  pm25  pm10   o3  no2  so2   co
# 0      2020/5/1   110    54   50    1    2    4
# 1      2020/5/2    68    71   36    1    3    2
# 2      2020/5/3    81    74   38    1    3    4
# 3      2020/5/4    77    49   37    2    2    4
# 4      2020/5/5    62    70   36    3    3    5
# ..          ...   ...   ...  ...  ...  ...  ...
# 533  2019/12/31         104   25   10    2   12
# 534    2019/6/1          87   44    3    3    7
# 535  2018/12/31         171   59   27    5   14
# 536  2018/11/29         108   62   13    2    9
# 537  2018/12/14          90   53   11    2    6
#
# [538 rows x 7 columns]

# %%
dataset=dataset.reset_index(drop=True)

# %%
training_set = dataset.iloc[:,4:5].values

# %%
training_set1=[]
for i in training_set:
    if i!=' ':
        training_set1.append(int(i[0].strip()))

# %%
training_set1 = np.array(training_set1)

# %%
training_set1 = training_set1.reshape(-1,1)

# %%
tested = training_set1[30:60]
training_set1 = training_set1[:60]

# %%
#Feature Scaling 
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set1)

# %%
testing = sc.transform(tested)
testing = np.array(testing)
testing = np.reshape(testing,(testing.shape[1],testing.shape[0],1))

# %%
training_set_scaled
# Out:
# array([[0.        ],
#        [0.        ],
#        [0.        ],
#        [0.07692308],
#        [0.15384615],
#        [0.07692308],
#        [0.07692308],
#        [0.07692308],
#        [0.07692308],
#        [0.07692308],
#        [0.15384615],
#        [0.15384615],
#        [0.23076923],
#        [0.15384615],
#        [0.07692308],
#        [0.07692308],
#        [0.07692308],
#        [0.07692308],
#        [0.07692308],
#        [0.07692308],
#        [0.        ],
#        [0.        ],
#        [0.07692308],
#        [0.23076923],
#        [0.23076923],
#        [0.23076923],
#        [0.38461538],
#        [0.30769231],
#        [0.23076923],
#        [0.15384615],
#        [0.23076923],
#        [0.30769231],
#        [0.46153846],
#        [0.30769231],
#        [0.38461538],
#        [0.46153846],
#        [0.38461538],
#        [0.23076923],
#        [0.23076923],
#        [0.30769231],
#        [0.15384615],
#        [0.38461538],
#        [0.30769231],
# ...

# %%
training_set_scaled
# Out:
# array([[0.        ],
#        [0.        ],
#        [0.        ],
#        [0.07692308],
#        [0.15384615],
#        [0.07692308],
#        [0.07692308],
#        [0.07692308],
#        [0.07692308],
#        [0.07692308],
#        [0.15384615],
#        [0.15384615],
#        [0.23076923],
#        [0.15384615],
#        [0.07692308],
#        [0.07692308],
#        [0.07692308],
#        [0.07692308],
#        [0.07692308],
#        [0.07692308],
#        [0.        ],
#        [0.        ],
#        [0.07692308],
#        [0.23076923],
#        [0.23076923],
#        [0.23076923],
#        [0.38461538],
#        [0.30769231],
#        [0.23076923],
#        [0.15384615],
#        [0.23076923],
#        [0.30769231],
#        [0.46153846],
#        [0.30769231],
#        [0.38461538],
#        [0.46153846],
#        [0.38461538],
#        [0.23076923],
#        [0.23076923],
#        [0.30769231],
#        [0.15384615],
#        [0.38461538],
#        [0.30769231],
# ...

# %%
tested
# Out:
# array([[ 4],
#        [ 5],
#        [ 7],
#        [ 5],
#        [ 6],
#        [ 7],
#        [ 6],
#        [ 4],
#        [ 4],
#        [ 5],
#        [ 3],
#        [ 6],
#        [ 5],
#        [ 5],
#        [ 5],
#        [ 3],
#        [ 2],
#        [ 2],
#        [ 2],
#        [ 2],
#        [ 4],
#        [ 4],
#        [ 3],
#        [13],
#        [14],
#        [ 8],
#        [10],
#        [ 7],
#        [10],
#        [ 8]])

# %%
x_train = []
y_train = []
n_future = 4 # next 4 days temperature forecast
n_past = 30 # Past 30 days

# %%
for i in range(0,len(training_set_scaled)-n_past-n_future+1):
    x_train.append(training_set_scaled[i : i + n_past , 0])     
    y_train.append(training_set_scaled[i + n_past : i + n_past + n_future , 0 ])

# %%
x_train , y_train = np.array(x_train), np.array(y_train)

# %%
x_train
# Out:
# array([[0.        , 0.        , 0.        , 0.07692308, 0.15384615,
#         0.07692308, 0.07692308, 0.07692308, 0.07692308, 0.07692308,
#         0.15384615, 0.15384615, 0.23076923, 0.15384615, 0.07692308,
#         0.07692308, 0.07692308, 0.07692308, 0.07692308, 0.07692308,
#         0.        , 0.        , 0.07692308, 0.23076923, 0.23076923,
#         0.23076923, 0.38461538, 0.30769231, 0.23076923, 0.15384615],
#        [0.        , 0.        , 0.07692308, 0.15384615, 0.07692308,
#         0.07692308, 0.07692308, 0.07692308, 0.07692308, 0.15384615,
#         0.15384615, 0.23076923, 0.15384615, 0.07692308, 0.07692308,
#         0.07692308, 0.07692308, 0.07692308, 0.07692308, 0.        ,
#         0.        , 0.07692308, 0.23076923, 0.23076923, 0.23076923,
#         0.38461538, 0.30769231, 0.23076923, 0.15384615, 0.23076923],
#        [0.        , 0.07692308, 0.15384615, 0.07692308, 0.07692308,
#         0.07692308, 0.07692308, 0.07692308, 0.15384615, 0.15384615,
# ...

# %%
x_train.shape[1]
# Out:
# 30

# %%
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1) )

# %%
from keras.models import Sequential
from keras.layers import LSTM,Dense ,Dropout
# Fitting RNN to training set using Keras Callbacks. Read Keras callbacks docs for more info.
# Out:
# Using TensorFlow backend.

# %%
regressor = Sequential()
regressor.add((LSTM(units=30, return_sequences=True, input_shape = (x_train.shape[1],1) ) ))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units= 30 , return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units= 30 , return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units= 30))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = n_future,activation='linear'))
regressor.compile(optimizer='adam', loss='mean_squared_error',metrics=['acc'])
regressor.fit(x_train, y_train, epochs=500,batch_size=32 )
# Out:
# Epoch 1/500
# 27/27 [==============================] - 2s 56ms/step - loss: 0.1802 - acc: 0.2963
# Epoch 2/500
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1670 - acc: 0.3704
# Epoch 3/500
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1542 - acc: 0.3333
# Epoch 4/500
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1433 - acc: 0.3704
# Epoch 5/500
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1286 - acc: 0.2963
# Epoch 6/500
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1144 - acc: 0.2593
# Epoch 7/500
# 27/27 [==============================] - 0s 955us/step - loss: 0.1011 - acc: 0.2963
# Epoch 8/500
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0914 - acc: 0.2963
# Epoch 9/500
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0731 - acc: 0.3333
# Epoch 10/500
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0623 - acc: 0.1852
# Epoch 11/500
# ...

# %%
predicted_temperature = regressor.predict(testing)
predicted_temperature = sc.inverse_transform(predicted_temperature)
predicted_temperature = np.reshape(predicted_temperature,(predicted_temperature.shape[1],predicted_temperature.shape[0]))

# %%
predicted_temperature
# Out:
# array([[12.055286 ],
#        [ 8.8290415],
#        [ 8.163499 ],
#        [ 8.459897 ]], dtype=float32)

# %%
real_temperature = pd.read_csv('data.csv')
real_temperature = real_temperature.iloc[60:64,4:5].values

# %%
real_temperature
# Out:
# array([[' 8'],
#        [' 10'],
#        [' 9'],
#        [' 6']], dtype=object)
